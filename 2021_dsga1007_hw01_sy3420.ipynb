# %% [markdown]
# ---
#
# ### DSGA1007
#
# ---
#
# ### HW01
# ### Due Date: 2021-09-24, 5PM

# %% [markdown]
# Firstname: Seonhye
#
# Lastname: Yang
#
# E-mail: sy3420@nyu.edu
#
#
# ---
#
# Enter your solutions below,  and submit this notebook

# %% [markdown]
# ### Problem 01 (25 points):
#
# Two given data sets "ClassA.csv" and "ClassB.csv" represent the number of points obtained by students at quizzes for two different classes A and B.
#
# So, every row in "ClassA.csv" represents points obtained by a student in class A. Similarly for the class B.
#
# Write a function which displays:
#
# - number of students for each A and B
#
# - number of quizzes for each class A and B
#
#
# - the average number of points for every student for each class A and B
#
# - the min number of points for every student for each class A and B
#
# - the max number of points for every student for each class A and B
#
# - the standard deviation of the number of points for every student for each class A and B
#
#
# - the average number of points over for every quiz for each class A and B
#
# - the min number of points over for every quiz for each class A and B
#
# - the max number of points over for every quiz for each class A and B
#
# - the standard deviation for the number of points over for every quiz for each class A and B

# %%
### Solution 01

def examine_results(ClassA, ClassB):
    pass

### run your solution
import pandas as pd
import numpy as np

class_a = pd.read_csv("ClassA.csv")
class_b = pd.read_csv("ClassB.csv")

def examine_results(class_a, class_b):
    print("num students a")
    print(len(class_a))
    print()
    print("num students b")
    print(len(class_b))
    print()
    print("num quizzes a")
    print(class_a.shape[1])
    print()
    print("num quizzes b")
    print(class_b.shape[1])
    print()
    print("avg points student a")
    print(np.mean(class_a, axis = 1))
    print()
    print("avg points student b")
    print(np.mean(class_b, axis = 1))
    print()
    print("min points student a")
    print(np.min(class_a, axis = 1))
    print()
    print("min points student b")
    print(np.min(class_b, axis = 1))
    print()
    print("max points student a")
    print(np.max(class_a, axis = 1))
    print()
    print("max points student b")
    print(np.max(class_b, axis = 1))
    print()
    print("stddev points student a")
    print(np.std(class_a, axis = 1))
    print()
    print("stddev points student b")
    print(np.std(class_b, axis = 1))
    print()
    print()
    print()
    print("avg points quiz a")
    print(np.mean(class_a, axis = 0))
    print()
    print("avg points quiz b")
    print(np.mean(class_b, axis = 0))
    print()
    print("min points quiz a")
    print(np.mean(class_a, axis = 0))
    print()
    print("min points quiz b")
    print(np.mean(class_b, axis = 0))
    print()
    print("max points quiz a")
    print(np.max(class_a, axis = 0))
    print()
    print("max points quiz b")
    print(np.max(class_b, axis = 0))
    print()
    print("stddev points quiz a")
    print(np.std(class_a, axis = 0))
    print()
    print("stddev points quiz b")
    print(np.std(class_b, axis = 0))
    print()

# %%
examine_results(class_a, class_b)
# Out:
# num students a
# 9
#
# num students b
# 9
#
# num quizzes a
# 5
#
# num quizzes b
# 5
#
# avg points student a
# 0    86.4
# 1    74.6
# 2    88.8
# 3    74.6
# 4    79.8
# 5    79.6
# 6    84.8
# 7    76.0
# 8    78.6
# dtype: float64
#
# avg points student b
# 0    82.2
# 1    88.4
# 2    76.2
# 3    82.6
# 4    80.0
# 5    82.4
# 6    78.6
# 7    79.8
# 8    78.2
# dtype: float64
#
# min points student a
# 0    61
# 1    60
# 2    74
# 3    61
# 4    72
# 5    70
# 6    68
# 7    63
# 8    61
# dtype: int64
#
# min points student b
# 0    71
# 1    80
# 2    67
# 3    77
# 4    73
# 5    68
# 6    73
# 7    67
# 8    68
# dtype: int64
#
# max points student a
# 0    98
# 1    91
# 2    98
# 3    87
# 4    96
# 5    90
# 6    94
# 7    92
# 8    98
# dtype: int64
#
# max points student b
# 0    88
# 1    93
# 2    88
# 3    92
# 4    89
# 5    94
# 6    89
# 7    88
# 8    91
# dtype: int64
#
# stddev points student a
# 0    13.093510
# 1    10.326665
# 2     8.423776
# 3     9.090655
# 4     8.634813
# 5     6.529931
# 6     8.997778
# 7     9.444575
# 8    12.338557
# dtype: float64
#
# stddev points student b
# 0    6.431174
# 1    4.841487
# 2    7.884161
# 3    5.607138
# 4    6.693280
# 5    8.639444
# 6    5.748043
# 7    8.328265
# 8    9.495262
# dtype: float64
#
#
#
# avg points quiz a
# 93    81.888889
# 79    81.000000
# 60    78.777778
# 85    78.111111
# 82    82.000000
# dtype: float64
#
# avg points quiz b
# 86    82.111111
# 76    81.444444
# 72    84.222222
# 92    79.444444
# 77    77.444444
# dtype: float64
#
# min points quiz a
# 93    81.888889
# 79    81.000000
# 60    78.777778
# 85    78.111111
# 82    82.000000
# dtype: float64
#
# min points quiz b
# 86    82.111111
# 76    81.444444
# 72    84.222222
# 92    79.444444
# 77    77.444444
# dtype: float64
#
# max points quiz a
# 93    95
# 79    98
# 60    96
# 85    98
# 82    98
# dtype: int64
#
# max points quiz b
# 86    94
# 76    93
# 72    91
# 92    88
# 77    92
# dtype: int64
#
# stddev points quiz a
# 93     9.048566
# 79    10.424331
# 60    13.982352
# 85     9.036278
# 82    11.125546
# dtype: float64
#
# stddev points quiz b
# 86    8.478003
# 76    9.081252
# 72    6.595921
# 92    5.272805
# 77    8.015417
# dtype: float64

# %% [markdown]
# ### Problem 02 (50 points)
#
#
# Create two random matrices of dimension 10 by 10:
#
# (5 points)
# a. $U$, where each entry is drawn independently from the uniform distribution on $[0, 1]$
#
# (5 points)
# b. $G$, where each entry is drawn independently from the normal (Gaussian) distribution with mean 0 and standard deviation 1.
#
#
# (30 points)
# - Write a function which for a given input matrix M outputs two vectors:
#
# avg_row, avg_col which are averages over rows and columns in the given matrix M
#
#
# ```
# def matrix_avg(M):
#     return avg_row, avg_col
# ```
#
# - Write a function which for a given input matrix M outputs a matrix where each entry of M is squared;
#
#
#
# ```
# def matrix_sq(M):
#     return M_sq
# ```
#
#
# - Write a function which for a given input matrix M outputs a matrix where each entry of M is raised at the power k:
#
#
# ```
# def matrix_power(M, k):
#     return M_power
# ```
#
#
# - Report outputs of when `matrix_avg`, `matrix_sq` and `matrix_power` for `k=3` applied on both $U$ and $G$;
# there are 6 outputs.
#
#
#
# (10 points)
#
# Write a function which displays the output of the convolution:
#
# `matrix_avg(matrix_power(M, t))` when $t$ takes values from $t=1, 2, \dots, 10$.
#
#
# ```
# def matrix_powers_examine(M):
#     return
# ```
#
# - Report output of the above on both $U$ and $G$.

# %%
### Solution 02

import numpy as np

#Create two random matrices of dimension 10 by 10
U = np.random.uniform(0, 1, size = (10,10))
G = np.random.normal(0, 1, size = (10, 10))

#functions
def matrix_avg(M):
    avg_row = np.mean(M, axis = 0)
    avg_col = np.mean(M, axis = 1)
    return avg_row, avg_col

def matrix_sq(M):
    M_sq = M**2
    return(M_sq)

def matrix_power(M, k):
    M_power = M**k
    return(M_power)

#Reporting outputs
u_avg = matrix_avg(U)
g_avg = matrix_avg(G)

print("u avg", u_avg)
print("u avg", g_avg)
print()

u_sq = matrix_sq(U)
g_sq = matrix_sq(G)

print("u sq", u_sq)
print("u sq", g_sq)
print()

u_pwr = matrix_power(U, 3)
g_pwr = matrix_power(G, 3)

print("u pwr", u_pwr)
print("u pwr", g_pwr)
print()

def matrix_powers_examine(M):
    for t in range(1,11):
        print(matrix_avg(matrix_power(M, t)))

print()
matrix_powers_examine(U)
print()
matrix_powers_examine(G)
# Out:
# u avg (array([0.3329693 , 0.48352012, 0.56776464, 0.52827981, 0.54251007,
#        0.52564325, 0.44883861, 0.33240539, 0.51144914, 0.59602342]), array([0.40494389, 0.39798923, 0.61509478, 0.50004097, 0.44452803,
#        0.66435351, 0.45900075, 0.38746027, 0.56880596, 0.42718636]))
# u avg (array([ 0.16730871,  0.25183944, -0.54854135, -0.55507402,  0.36639262,
#        -0.03315764,  0.10440129, -0.43122402,  0.12619331,  0.32828251]), array([ 0.06299959,  0.26607615, -0.01295558,  0.00525603,  0.21898714,
#        -0.20630609, -0.46096738, -0.46805502,  0.03443273,  0.33695327]))
#
# u sq [[6.05213186e-05 2.81232734e-01 1.04404311e-01 3.02492580e-01
#   1.69087952e-01 9.17730191e-01 1.79837235e-01 4.38256196e-03
#   5.18216083e-01 3.46979627e-03]
#  [1.53701259e-01 4.68850583e-01 3.87392044e-03 1.34871467e-02
#   2.96117117e-01 5.31775791e-02 8.63064339e-01 2.50343119e-02
#   3.50333300e-01 7.33594870e-02]
#  [4.44599967e-01 3.21072366e-02 8.06503426e-01 9.19067565e-03
#   1.86363850e-01 9.15992226e-01 3.41075400e-01 3.90429193e-01
#   9.30861061e-01 5.60418729e-01]
#  [5.68044595e-02 3.63175349e-02 3.31574279e-01 9.92111545e-01
#   3.06804067e-01 2.06288657e-01 2.63178557e-01 3.14783126e-01
#   1.47930190e-03 7.72663802e-01]
#  [2.79604014e-01 8.15510301e-01 3.06857280e-01 1.70634516e-02
#   8.67081509e-01 5.26838352e-03 2.01373351e-02 1.03994511e-03
#   6.42453024e-01 1.22103014e-01]
#  [6.88629365e-01 8.90473037e-01 3.08822854e-01 6.66285435e-01
#   4.72028984e-01 3.64862910e-01 3.13579776e-01 3.49646543e-01
#   4.86359043e-02 6.97490217e-01]
#  [2.42950378e-02 3.70498756e-01 2.88404354e-01 5.40920531e-01
#   3.62314893e-01 2.13648117e-02 3.21181771e-02 1.74323722e-01
#   4.88231061e-01 2.59470085e-01]
#  [2.84127340e-02 8.39696168e-02 8.88309481e-01 1.92753650e-02
#   5.30483948e-02 1.52801882e-02 2.09105354e-01 5.84627507e-02
#   9.55717871e-02 9.46293057e-01]
#  [2.28730816e-02 2.28107973e-01 5.14970780e-01 5.90638477e-01
#   8.88889627e-01 9.15894878e-01 1.40705687e-02 1.92825666e-02
#
#
# (array([0.3329693 , 0.48352012, 0.56776464, 0.52827981, 0.54251007,
#        0.52564325, 0.44883861, 0.33240539, 0.51144914, 0.59602342]), array([0.40494389, 0.39798923, 0.61509478, 0.50004097, 0.44452803,
#        0.66435351, 0.45900075, 0.38746027, 0.56880596, 0.42718636]))
# (array([0.17352573, 0.32078313, 0.38154493, 0.40257381, 0.36099919,
#        0.39831038, 0.25740441, 0.157945  , 0.36533434, 0.43281565]), array([0.2480914 , 0.2300999 , 0.46175418, 0.32820053, 0.30771183,
#        0.4800455 , 0.25619414, 0.23977287, 0.42023252, 0.27913368]))
# (array([0.11084919, 0.24184124, 0.27863557, 0.33749997, 0.26818732,
#        0.33913415, 0.16901685, 0.08402953, 0.28137613, 0.33935687]), array([0.17477524, 0.15894866, 0.37452888, 0.2454074 , 0.24247999,
#        0.36475118, 0.15550825, 0.19429703, 0.33757355, 0.20165664]))
# (array([0.07801455, 0.19556159, 0.21668051, 0.29264544, 0.21440571,
#        0.30211251, 0.12206704, 0.04671971, 0.22538722, 0.27798264]), array([0.13532339, 0.12077769, 0.31723443, 0.20008192, 0.20176077,
#        0.28718398, 0.09824748, 0.17521185, 0.28146442, 0.15429097]))
# (array([0.05772473, 0.16521881, 0.17698722, 0.25911985, 0.18043755,
#        0.27555085, 0.09508741, 0.02656268, 0.18561175, 0.23452616]), array([0.1121425 , 0.09743729, 0.27684677, 0.17320944, 0.17303028,
#        0.23248123, 0.06363174, 0.1641367 , 0.24059142, 0.12331965]))
# (array([0.04402092, 0.14371613, 0.14999718, 0.23325734, 0.15732683,
#        0.25498396, 0.07851969, 0.01531559, 0.15638637, 0.202236  ]), array([0.09738151, 0.08190997, 0.2469331 , 0.15615709, 0.15120157,
#        0.1924655 , 0.04198821, 0.15593279, 0.20972971, 0.10206056]))
# (array([0.03426297, 0.12752648, 0.13055548, 0.21289183, 0.14050257,
#        0.23821478, 0.06761102, 0.00892054, 0.1344334 , 0.17741841]), array([0.08724843, 0.07089602, 0.22384083, 0.14460178, 0.1337556 ,
#        0.16226563, 0.02813099, 0.14896744, 0.18580132, 0.08682944]))
# (array([0.0270632 , 0.11472378, 0.11578585, 0.19658164, 0.12750038,
#        0.22401067, 0.0598838 , 0.00523698, 0.11764792, 0.15784738]), array([0.07980775, 0.06265152, 0.20535892, 0.13626241, 0.11931097,
#        0.13884708, 0.01908833, 0.14266019, 0.1668156 , 0.07547885]))
# (array([0.02161169, 0.10419303, 0.10403672, 0.18332322, 0.11693684,
#        0.2116272 , 0.05401321, 0.00309431, 0.10460198, 0.14208785]), array([0.07402001, 0.05618744, 0.19009688, 0.12989496, 0.10705358,
#        0.12025872, 0.01309195, 0.13678232, 0.15142878, 0.06671142]))
# (array([0.01740231, 0.09526102, 0.09433304, 0.17239897, 0.1080084 ,
#        0.2005918 , 0.04927699, 0.00183814, 0.09429787, 0.12917024]), array([0.06929945, 0.05091658, 0.17715468, 0.12480217, 0.09647223,
#        0.10521041, 0.00906077, 0.13123374, 0.13870929, 0.05971947]))
#
# (array([ 0.16730871,  0.25183944, -0.54854135, -0.55507402,  0.36639262,
#           6.66533713, 1499.5123987 ,  192.42088315,   20.51799229,
#          25.31818179,   27.72686748]), array([1.93264927e+01, 3.54687377e+01, 3.43900390e+02, 1.48001132e-02,
#        1.37887983e+02, 1.18663207e+02, 4.76841018e+01, 1.65312137e+03,
#        7.98259626e-02, 2.29008534e+01]))

# %% [markdown]
# ### Problem 03 (25 points)
#
# For the given text below, write a function which displays the text and returns a dictionary call it `char_counts`; where the dictionary maps all distinct characters of the text into the number of their occurrences in the given text.
#
# For example, `char_counts['A'] = 1` since `A` only appeared once in the word "Avenue".
#
#
# Finally, print the obtained dictionary `char_counts` and its length.

# %%
text = "The Center for Data Science (CDS) is the focal point for New York University’s university-wide efforts in Data Science. The Center was established in 2013 to advance NYU’s goal of creating a world-leading Data Science training and research facility, and arming researchers and professionals with the tools to harness the power of Big Data. Today, CDS counts 16 jointly appointed interdisciplinary faculty housed on two floors of our magnificent 60 5th Avenue building, one of New York City’s historic properties. It is home to a top-ranked MS in Data Science program, one of the first PhD programs in Data Science, and a new undergraduate program in Data Science, as well as a lively Fellow and Postdoctoral program. It has over 60 associate and affiliate faculty from 25 departments in 9 schools and units. With cross-disciplinary research and innovative educational programs, CDS is shaping the new field of Data Science."

# %%
### Solution 03 

#you can print the whole dictionary. first the character count and then the length. so it will be in one line. 

def text_process(text):
    print(text) # Display the text
    
    char_counts = dict()
    for char in text:
        if char_counts.get(char) is not None:
            char_counts[char] = char_counts[char] + 1
        else:
            char_counts[char] = 1
            
    return char_counts

char_counts = text_process(text)

print()
print(len(char_counts))
print()

for i in char_counts.items():
    print(i)
# Out:
# The Center for Data Science (CDS) is the focal point for New York University’s university-wide efforts in Data Science. The Center was established in 2013 to advance NYU’s goal of creating a world-leading Data Science training and research facility, and arming researchers and professionals with the tools to harness the power of Big Data. Today, CDS counts 16 jointly appointed interdisciplinary faculty housed on two floors of our magnificent 60 5th Avenue building, one of New York City’s historic properties. It is home to a top-ranked MS in Data Science program, one of the first PhD programs in Data Science, and a new undergraduate program in Data Science, as well as a lively Fellow and Postdoctoral program. It has over 60 associate and affiliate faculty from 25 departments in 9 schools and units. With cross-disciplinary research and innovative educational programs, CDS is shaping the new field of Data Science.
#
# 51
#
# ('T', 3)
# ('h', 22)
# ('e', 73)
# (' ', 148)
# ('C', 6)
# ('n', 57)
# ('t', 55)
# ('r', 50)
# ('f', 22)
# ('o', 56)
# ('D', 12)
# ('a', 72)
# ('S', 11)
# ('c', 33)
# ('i', 62)
# ('(', 1)
# (')', 1)
# ('s', 45)
# ('l', 26)
# ('p', 17)
# ('N', 3)
# ('w', 12)
# ('Y', 3)
# ('k', 3)
# ('U', 2)
# ('v', 8)
# ('y', 11)
# ('’', 3)
# ('u', 12)
# ('-', 4)
# ('d', 26)
# ('.', 6)
# ('b', 2)
# ('2', 2)
# ('0', 3)
# ('1', 2)
# ('3', 1)
# ('g', 15)
# (',', 7)
# ('m', 10)
# ('B', 1)
# ('6', 3)
# ('j', 1)
# ('5', 2)
# ('A', 1)
# ('I', 2)
# ('M', 1)
# ('P', 2)
# ('F', 1)
# ('9', 1)
# ('W', 1)
